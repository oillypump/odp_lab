# %%
import pandas as pd
import pyarrow as pa

from pyiceberg.catalog import load_catalog
from pyiceberg.schema import Schema
from pyiceberg.types import (
    NestedField,
    StringType,
    DoubleType,
    IntegerType
)

# 1. Read CSV
df = pd.read_csv("Sample-Superstore.csv", encoding="latin-1")
table_arrow = pa.Table.from_pandas(df)

# %%
# 2. Load Iceberg catalog (Hive)
catalog = load_catalog(
    name="hive",
    **{
        "type": "hive",
        "uri": "thrift://hive-metastore:9083",
        "warehouse": "s3a://lakehouse/bronze",
        "s3.endpoint": "http://minio:9000",
        "s3.access-key-id": "minio",
        "s3.secret-access-key": "minio123",
        "s3.path-style-access": "true",
        "s3.region": "us-east-1",
    }
)

# %%
# 3. Define Iceberg schema
schema = Schema(
    NestedField(1, "Row ID", IntegerType(), required=False),
    NestedField(2, "Order ID", StringType(), required=False),
    NestedField(3, "Sales", DoubleType(), required=False),
)

# Namespace & table
namespace = "bronze"
table_name = "superstore"
identifier = f"{namespace}.{table_name}"

# %%
namespace = "bronze"
table_name = "superstore"
identifier = f"{namespace}.{table_name}"

# 1. Create namespace jika belum ada
namespaces = [ns[0] for ns in catalog.list_namespaces()]
if namespace not in namespaces:
    catalog.create_namespace(namespace)

# 2. Create table jika belum ada
if not catalog.table_exists(identifier):
    catalog.create_table(
        identifier=identifier,
        schema=schema,
        location="s3a://lakehouse/bronze/superstore"
    )

# 3. Load table
table = catalog.load_table(identifier)

# %%
# print(table.schema())
# # print(table_arrow.schema)
df = table
print(df)
# Out:
# superstore(
#   1: Row ID: optional int,
#   2: Order ID: optional string,
#   3: Sales: optional double
# ),
# partition by: [],
# sort order: [],
# snapshot: null

# %%
# 5. Append data
table.append(table_arrow)

print("✅ Data successfully written to Iceberg table in MinIO")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/werk/ODP_Lab/.venv/lib/python3.12/site-packages/pyiceberg/io/pyarrow.py:2615, in _check_pyarrow_schema_compatible(requested_schema, provided_schema, downcast_ns_timestamp_to_us, format_version)
#    2614 try:
# -> 2615     provided_schema = pyarrow_to_schema(
#    2616         provided_schema,
#    2617         name_mapping=name_mapping,
#    2618         downcast_ns_timestamp_to_us=downcast_ns_timestamp_to_us,
#    2619         format_version=format_version,
#    2620     )
#    2621 except ValueError as e:
#
# File ~/werk/ODP_Lab/.venv/lib/python3.12/site-packages/pyiceberg/io/pyarrow.py:1072, in pyarrow_to_schema(schema, name_mapping, downcast_ns_timestamp_to_us, format_version)
#    1069     schema_without_ids = _pyarrow_to_schema_without_ids(
#    1070         schema, downcast_ns_timestamp_to_us=downcast_ns_timestamp_to_us, format_version=format_version
#    1071     )
# -> 1072     return apply_name_mapping(schema_without_ids, name_mapping)
#    1073 else:
#
# File ~/werk/ODP_Lab/.venv/lib/python3.12/site-packages/pyiceberg/table/name_mapping.py:372, in apply_name_mapping(schema_without_ids, name_mapping)
#     371 def apply_name_mapping(schema_without_ids: Schema, name_mapping: NameMapping) -> Schema:
# --> 372     return visit_with_partner(schema_without_ids, name_mapping, NameMappingProjectionVisitor(), NameMappingAccessor())
#
# File /usr/lib/python3.12/functools.py:909, in singledispatch.<locals>.wrapper(*args, **kw)
#     906     raise TypeError(f'{funcname} requires at least '
#     907                     '1 positional argument')
# --> 909 return dispatch(args[0].__class__)(*args, **kw)
#
# File ~/werk/ODP_Lab/.venv/lib/python3.12/site-packages/pyiceberg/schema.py:665, in _(schema, partner, visitor, accessor)
#     664 struct_partner = accessor.schema_partner(partner)
# --> 665 return visitor.schema(schema, partner, visit_with_partner(schema.as_struct(), struct_partner, visitor, accessor))
#
# File /usr/lib/python3.12/functools.py:909, in singledispatch.<locals>.wrapper(*args, **kw)
#     906     raise TypeError(f'{funcname} requires at least '
#     907                     '1 positional argument')
# --> 909 return dispatch(args[0].__class__)(*args, **kw)
#
# File ~/werk/ODP_Lab/.venv/lib/python3.12/site-packages/pyiceberg/schema.py:675, in _(struct, partner, visitor, accessor)
#     674 try:
# --> 675     field_result = visit_with_partner(field.field_type, field_partner, visitor, accessor)  # type: ignore
#     676     field_results.append(visitor.field(field, field_partner, field_result))
#
# File /usr/lib/python3.12/functools.py:909, in singledispatch.<locals>.wrapper(*args, **kw)
#     906     raise TypeError(f'{funcname} requires at least '
#     907                     '1 positional argument')
# --> 909 return dispatch(args[0].__class__)(*args, **kw)
#
# File ~/werk/ODP_Lab/.venv/lib/python3.12/site-packages/pyiceberg/schema.py:715, in _(primitive, partner, visitor, _)
#     713 @visit_with_partner.register(PrimitiveType)
#     714 def _(primitive: PrimitiveType, partner: P, visitor: SchemaWithPartnerVisitor[P, T], _: PartnerAccessor[P]) -> T:
# --> 715     return visitor.primitive(primitive, partner)
#
# File ~/werk/ODP_Lab/.venv/lib/python3.12/site-packages/pyiceberg/table/name_mapping.py:366, in NameMappingProjectionVisitor.primitive(self, primitive, primitive_partner)
#     365 if primitive_partner is None:
# --> 366     raise ValueError(f"Could not find field with name: {'.'.join(self.current_path)}")
#     368 return primitive
#
# ValueError: Could not find field with name: Order Date
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 2
#       1 # 5. Append data
# ----> 2 table.append(table_arrow)
#       4 print("✅ Data successfully written to Iceberg table in MinIO")
#
# File ~/werk/ODP_Lab/.venv/lib/python3.12/site-packages/pyiceberg/table/__init__.py:1362, in Table.append(self, df, snapshot_properties, branch)
#    1353 """
#    1354 Shorthand API for appending a PyArrow table to the table.
#    1355
#    (...)   1359     branch: Branch Reference to run the append operation
#    1360 """
#    1361 with self.transaction() as tx:
# -> 1362     tx.append(df=df, snapshot_properties=snapshot_properties, branch=branch)
#
# File ~/werk/ODP_Lab/.venv/lib/python3.12/site-packages/pyiceberg/table/__init__.py:475, in Transaction.append(self, df, snapshot_properties, branch)
#     472     raise ValueError(f"Expected PyArrow table, got: {df}")
#     474 downcast_ns_timestamp_to_us = Config().get_bool(DOWNCAST_NS_TIMESTAMP_TO_US_ON_WRITE) or False
# --> 475 _check_pyarrow_schema_compatible(
#     476     self.table_metadata.schema(),
#     477     provided_schema=df.schema,
#     478     downcast_ns_timestamp_to_us=downcast_ns_timestamp_to_us,
#     479     format_version=self.table_metadata.format_version,
#     480 )
#     482 with self._append_snapshot_producer(snapshot_properties, branch=branch) as append_files:
#     483     # skip writing data files if the dataframe is empty
#     484     if df.shape[0] > 0:
#
# File ~/werk/ODP_Lab/.venv/lib/python3.12/site-packages/pyiceberg/io/pyarrow.py:2626, in _check_pyarrow_schema_compatible(requested_schema, provided_schema, downcast_ns_timestamp_to_us, format_version)
#    2622     provided_schema = _pyarrow_to_schema_without_ids(
#    2623         provided_schema, downcast_ns_timestamp_to_us=downcast_ns_timestamp_to_us, format_version=format_version
#    2624     )
#    2625     additional_names = set(provided_schema._name_to_id.keys()) - set(requested_schema._name_to_id.keys())
# -> 2626     raise ValueError(
#    2627         f"PyArrow table contains more columns: {', '.join(sorted(additional_names))}. Update the schema first (hint, use union_by_name)."
#    2628     ) from e
#    2629 _check_schema_compatible(requested_schema, provided_schema)
#
# ValueError: PyArrow table contains more columns: Category, City, Country, Customer ID, Customer Name, Discount, Order Date, Postal Code, Product ID, Product Name, Profit, Quantity, Region, Segment, Ship Date, Ship Mode, State, Sub-Category. Update the schema first (hint, use union_by_name).
